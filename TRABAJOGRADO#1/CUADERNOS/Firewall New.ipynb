# %% [markdown]
# # Firewall New

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
enlace = "H:\Mi unidad\Trabajo de grado 2\DATAFRAME SOLOS PROPUESTA TAMURA\Data Base_PROPUESTA TAMURA\Firewall_NeW.csv"
df=pd.read_csv(enlace)

# %%
df.head()
# Out:
#        timestamp json.geoip_region  \
# 0  1712452980749                VA
# 1  1712452980749                MO
# 2  1712452980752                VA
# 3  1712452981801                VA
# 4  1712452981801                 L
#
#                                     json.source_data json.destination_address  \
# 0  <189>logver=702081639 timestamp=1712434980 dev...               20.7.2.167
# 1  <189>logver=702081639 timestamp=1712434979 dev...            34.117.121.53
# 2  <189>logver=704032573 timestamp=1712434981 dev...            18.214.137.65
# 3  <189>logver=704002360 timestamp=1712434979 dev...              20.42.65.93
# 4  <189>logver=704002360 timestamp=1712434979 dev...           40.127.169.103
#
#    json.destination_port json.geoip_country_name json.source_address  \
# 0                    443           United States       172.24.117.60
# 1                    443           United States        172.24.60.47
# 2                     80           United States        172.24.31.17
# ...

# %% [markdown]
# # Visualización y agrupación por hora

# %% [markdown]
# # 1. json.geoip_region

# %%
df["json.geoip_region"].unique()
# Out:
# array(['VA', 'MO', 'L', 'DC', 'SP', 'CA', 'NH', 'CUN', 'FL', 'IA', 'TX',
#        'MH', 'ENG', 'LU', 'OR', 'AZ', '18', '75', 'IL', 'HE', 'NSW', 'BJ',
#        'NY', 'NV', '14', '27', 'WA', 'ON', 'OH', 'GA', 'VIC', 'RJ', 'NJ',
#        'WY', 'QC', 'SC', 'B', 'PA', '13', 'CRF', 'RM', 'MA', 'M', 'LMA',
#        'NI', 'UT', 'TA', 'BE', '04'], dtype=object)

# %% [markdown]
# | **Código** | **Región**                           | **País**                |
# |------------|--------------------------------------|-------------------------|
# | VA         | Virginia                             | Estados Unidos          |
# | MO         | Missouri                             | Estados Unidos          |
# | DC         | Distrito de Columbia (Washington D.C.) | Estados Unidos          |
# | CA         | California                           | Estados Unidos          |
# | NH         | New Hampshire                        | Estados Unidos          |
# | FL         | Florida                              | Estados Unidos          |
# | IA         | Iowa                                 | Estados Unidos          |
# | TX         | Texas                                | Estados Unidos          |
# | NY         | Nueva York                           | Estados Unidos          |
# | NV         | Nevada                               | Estados Unidos          |
# | IL         | Illinois                             | Estados Unidos          |
# | OH         | Ohio                                 | Estados Unidos          |
# | GA         | Georgia                              | Estados Unidos          |
# | WA         | Washington                           | Estados Unidos          |
# | NJ         | Nueva Jersey                         | Estados Unidos          |
# | PA         | Pennsylvania                         | Estados Unidos          |
# | MA         | Massachusetts                        | Estados Unidos          |
# | UT         | Utah                                 | Estados Unidos          |
# | WY         | Wyoming                              | Estados Unidos          |
# | RJ         | Rio de Janeiro                       | Brasil                  |
# | SP         | São Paulo                            | Brasil                  |
# | B          | (Podría referirse a una región en Brasil) | Brasil                  |
# | CRF        | (Podría ser un código específico a ciertas regiones o contextos en Brasil) | Brasil                  |
# | ON         | Ontario                              | Canadá                  |
# | QC         | Quebec                               | Canadá                  |
# | CUN        | Cancún                               | México                  |
# | ENG        | Inglaterra                           | Reino Unido             |
# | LU         | Luxemburgo                           | Luxemburgo              |
# | NSW        | Nueva Gales del Sur                  | Australia               |
# | BJ         | Benín                                | Benín                   |
# | BE         | Bélgica                              | Bélgica                 |
# | NI         | Nicaragua                            | Nicaragua               |
# | TA         | (Podría ser un código específico)    | (Contexto no claro)     |
# | VIC        | Victoria                             | Australia               |

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.geoip_region']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 100 registros
top_100 = df_agrupado.head(300).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(30, 7))

# Graficar cada 'json.geoip_region' individualmente
for address in top_100['json.geoip_region'].unique():
    subset = top_100[top_100['json.geoip_region'] == address]
    plt.scatter(subset['hora'], subset['count'], label=address)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Región')
plt.legend(title='Región', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=8)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. json.destination_port

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.destination_port']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 80 registros
top_100 = df_agrupado.head(200).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(30, 7))

# Graficar cada 'json.destination_port' individualmente
for port in top_100['json.destination_port'].unique():
    subset = top_100[top_100['json.destination_port'] == port]
    plt.scatter(subset['hora'], subset['count'], label=port)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Puerto de Destino')
plt.legend(title='Puerto de Destino', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=7)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()

# %% [markdown]
# * El puerto 443 es el puerto estándar utilizado para HTTPS (Hypertext Transfer Protocol Secure). HTTPS es una extensión segura del protocolo HTTP (Hypertext Transfer Protocol) que se utiliza para asegurar la comunicación entre el navegador web del usuario y el servidor web.

# %% [markdown]
# * El puerto 8081 es comúnmente utilizado como un puerto alternativo para servicios web y aplicaciones. Aunque no tiene un uso estándar tan definido como el puerto 80 (HTTP) o el puerto 443 (HTTPS), a menudo se usa en varias situaciones:
#
# >> Usos Comunes del Puerto 8081:
# Servidor Web Alternativo:
#
#  >> Puede usarse como un puerto alternativo para servicios HTTP o HTTPS cuando el puerto 80 o 443 está ocupado o no es accesible.
# Aplicaciones de Desarrollo:
#
# >> Se utiliza frecuentemente en entornos de desarrollo y prueba para ejecutar aplicaciones web localmente sin interferir con los puertos estándar.
# Servicios de Proxy o Proxy Inverso:
#
# >> A veces se usa para servicios de proxy, incluyendo servidores proxy inversos que redirigen el tráfico a otros servidores.

# %% [markdown]
# # 3. Pais de Origen : json.geoip_country_name

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.geoip_country_name']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 80 registros
top_100 = df_agrupado.head(300).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(20, 7))

# Graficar cada 'json.destination_port' individualmente
for port in top_100['json.geoip_country_name'].unique():
    subset = top_100[top_100['json.geoip_country_name'] == port]
    plt.scatter(subset['hora'], subset['count'], label=port)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Pais de Destino')
plt.legend(title='Pais de Destino', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=7)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4 Organización: json.geoip_organization

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.geoip_organization']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 300 registros
top_100 = df_agrupado.head(300).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(20, 7))

# Graficar cada 'json.destination_port' individualmente
for port in top_100['json.geoip_organization'].unique():
    subset = top_100[top_100['json.geoip_organization'] == port]
    plt.scatter(subset['hora'], subset['count'], label=port)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Organización')
plt.legend(title='Organización destino', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=7)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Usuario: 	json.r7_context.user.name

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.r7_context.user.name']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 300 registros
top_100 = df_agrupado.head(300).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(20, 7))

# Graficar cada 'json.destination_port' individualmente
for port in top_100['json.r7_context.user.name'].unique():
    subset = top_100[top_100['json.r7_context.user.name'] == port]
    plt.scatter(subset['hora'], subset['count'], label=port)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Usuario')
plt.legend(title='Usuario', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=7)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_8368\589982186.py:23: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # 6. Estado: 	json.connection_status

# %%
# 1. Agrupar y contar ocurrencias
df_agrupado = df.groupby(['hora', 'json.connection_status']).size().reset_index(name='count')

# Ordenar df_agrupado por la columna 'count' en orden descendente
df_agrupado = df_agrupado.sort_values(by='count', ascending=False)

# Seleccionar los primeros 80 registros
top_100 = df_agrupado.head(300).sort_values(by='hora')

# Crear el diagrama de puntos
plt.figure(figsize=(20, 7))

# Graficar cada 'json.destination_port' individualmente
for port in top_100['json.connection_status'].unique():
    subset = top_100[top_100['json.connection_status'] == port]
    plt.scatter(subset['hora'], subset['count'], label=port)

plt.xlabel('Hora')
plt.ylabel('Count')
plt.title('Diagrama de Puntos: Hora vs Estado')
plt.legend(title='Estado', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90, fontsize=7)  # Ajusta el tamaño de la fuente según sea necesario
plt.tight_layout()
plt.show()

# %% [markdown]
# # Agrupación por Fechas
